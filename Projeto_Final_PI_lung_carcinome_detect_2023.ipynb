# %% [markdown]
# <a href="https://colab.research.google.com/github/rmorraye/Image-Processing-medical-filters-py/blob/main/Projeto_Final_PI_lung_carcinome_detect_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Conectar ao google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importar as bibliotecas do opencv
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
from skimage.io import imread_collection

# Caminho para a imagem (mude caso tente executar em sua máquina)
path_1 = '/content/drive/MyDrive/1. Disciplinas Materias/2023.1 - PIM/Projeto/database/t1.jpg' # imagem 1
path_2 = '/content/drive/MyDrive/1. Disciplinas Materias/2023.1 - PIM/Projeto/database/t2.jpg' # imagem 2

# Ler e plotar
#   Imagem 1
img_src_1 = cv2.imread(path_1)
cv2_imshow(img_src_1)

#   Imagem 2
img_src_2 = cv2.imread(path_2)
cv2_imshow(img_src_2)
# Out:
# <PIL.Image.Image image mode=RGB size=405x434 at 0x7F55A568D990>
# <PIL.Image.Image image mode=RGB size=875x840 at 0x7F55A568FC40>

# %%
# Aplicar e printar a imagem com median blur com ksize = 21
#   Imagem 1
blurred_1 = cv2.medianBlur(img_src_1, 21)
cv2_imshow(blurred_1)

#   Imagem 2
blurred_2 = cv2.medianBlur(img_src_2, 21)
cv2_imshow(blurred_2)
# Out:
# <PIL.Image.Image image mode=RGB size=405x434 at 0x7F55A568E470>
# <PIL.Image.Image image mode=RGB size=875x840 at 0x7F55A568FA30>

# %%
#   Imagem 1
# Aplicação da mascara para detecção de bordas na imagem sem blur
edgesx_1 = cv2.Scharr(img_src_1, -1, dx=1, dy=0, scale=0.75,
                       delta=0, borderType=cv2.BORDER_DEFAULT)
edgesy_1 = cv2.Scharr(img_src_1, -1, dx=0, dy=1, scale=0.75,
                       delta=0, borderType=cv2.BORDER_DEFAULT)
edges1_1 = edgesx_1 + edgesy_1

# Print do resultado do processamento
cv2_imshow(edges1_1)


# Aplicação da mascara para detecção de bordas na imagem com blur
edgesx_1 = cv2.Scharr(blurred_1, -1, dx=1, dy=0, scale=1,
                       delta=0, borderType=cv2.BORDER_DEFAULT)
edgesy_1 = cv2.Scharr(blurred_1, -1, dx=0, dy=1, scale=0.75,
                       delta=0, borderType=cv2.BORDER_DEFAULT)
edges2_1 = edgesx_1 + edgesy_1

# Print do resultado do processamento
cv2_imshow(edges2_1)
# Out:
# <PIL.Image.Image image mode=RGB size=405x434 at 0x7F55A568FBE0>
# <PIL.Image.Image image mode=RGB size=405x434 at 0x7F55A568D180>

# %%
#   Imagem 2
# Aplicação da mascara para detecção de bordas na imagem sem blur
edgesx_2 = cv2.Scharr(img_src_2, -1, dx=1, dy=0, scale=0.75,
                       delta=0, borderType=cv2.BORDER_DEFAULT)
edgesy_2 = cv2.Scharr(img_src_2, -1, dx=0, dy=1, scale=0.75,
                       delta=0, borderType=cv2.BORDER_DEFAULT)
edges1_2 = edgesx_2 + edgesy_2

# Print do resultado do processamento
cv2_imshow(edges1_2)


# Aplicação da mascara para detecção de bordas na imagem com blur
edgesx_2 = cv2.Scharr(blurred_2, -1, dx=1, dy=0, scale=1,
                       delta=0, borderType=cv2.BORDER_DEFAULT)
edgesy_2 = cv2.Scharr(blurred_2, -1, dx=0, dy=1, scale=0.75,
                       delta=0, borderType=cv2.BORDER_DEFAULT)
edges2_2 = edgesx_2 + edgesy_2

# Print do resultado do processamento
cv2_imshow(edges2_2)
# Out:
# <PIL.Image.Image image mode=RGB size=875x840 at 0x7F55A568D9C0>
# <PIL.Image.Image image mode=RGB size=875x840 at 0x7F55A568DBD0>
