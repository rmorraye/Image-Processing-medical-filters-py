# %% [markdown]
# <a href="https://colab.research.google.com/github/rmorraye/Image-Processing-medical-filters-py/blob/main/Projeto_Final_PI_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Conectar ao google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importar as bibliotecas do opencv
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# Caminho para a imagem (mude caso tente executar em sua máquina)
path = '/content/drive/MyDrive/PIM - 2023/Projeto/database/t1.jpg'

# Ler e printar a imagem
img_src = cv2.imread(path)
cv2_imshow(img_src)
# Out:
# <PIL.Image.Image image mode=RGB size=405x434 at 0x7F12CC5C7C10>

# %%
# Aplicar e printar a imagem com median blur com ksize = 21
blurred = cv2.medianBlur(img_src, 21)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=RGB size=405x434 at 0x7F12CC5C7C70>

# %%
# Aplicação da mascara para detecção de bordas na imagem sem blur
edgesx = cv2.Scharr(img_src, -1, dx=1, dy=0, scale=0.75,
                       delta=0, borderType=cv2.BORDER_DEFAULT)
edgesy = cv2.Scharr(img_src, -1, dx=0, dy=1, scale=0.75,
                       delta=0, borderType=cv2.BORDER_DEFAULT)
edges1 = edgesx + edgesy

# Print do resultado do processamento
cv2_imshow(edges1)


# Aplicação da mascara para detecção de bordas na imagem com blur
edgesx = cv2.Scharr(blurred, -1, dx=1, dy=0, scale=1,
                       delta=0, borderType=cv2.BORDER_DEFAULT)
edgesy = cv2.Scharr(blurred, -1, dx=0, dy=1, scale=0.75,
                       delta=0, borderType=cv2.BORDER_DEFAULT)
edges2 = edgesx + edgesy

# Print do resultado do processamento
cv2_imshow(edges2)
# Out:
# <PIL.Image.Image image mode=RGB size=405x434 at 0x7F12CC3D3F40>
# <PIL.Image.Image image mode=RGB size=405x434 at 0x7F12CC3D3B50>
